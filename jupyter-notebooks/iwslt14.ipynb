# %% [markdown]
# # Notebook zur Bachelorarbeit
#
# Mit diesem Notebook kann ein Modell zur neuronalen maschinellen Übersetzung trainiert und evaluiert werden.
#
# ## Installation von Joey NMT

# %%
# !pip install joeynmt

# %% [markdown]
# ## Training eines Modells

# %%
# !python3 -m joeynmt train configs/iwslt14_deen_bpe.yaml

# %% [markdown]
# ## Evaluation des Modells

# %%
# !python3 -m joeynmt test configs/iwslt14_deen_bpe.yaml --output_path models/iwslt14_deen_bpe/predictions
